# %%
from bertopic import BERTopic
from sklearn.datasets import fetch_20newsgroups
import pandas
import numpy

# %%
# Out:
# <function fetch_20newsgroups at 0xfffefdd79120>

# %%
docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']

topic_model = BERTopic()
topics, probs = topic_model.fit_transform(docs)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 1105.51s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 1105.69s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 1105.91s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 1106.10s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 1106.31s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.

# %%
topic_model.get_topic(0)
# Out:
# [('game', 0.010610859507810554),
#  ('team', 0.00923772246970489),
#  ('games', 0.007353926372712871),
#  ('he', 0.007276520799724214),
#  ('players', 0.006425020770623693),
#  ('season', 0.006354224820692129),
#  ('hockey', 0.0062517380838287215),
#  ('play', 0.005911104524705724),
#  ('25', 0.005785557253810952),
#  ('year', 0.005749737765138911)]

# %%
topic_model.get_document_info(docs)
# Out:
#                                                 Document  Topic  \
# 0      \n\nI am sure some bashers of Pens fans are pr...      0
# 1      My brother is in the market for a high-perform...      4
# 2      \n\n\n\n\tFinally you said what you dream abou...     16
# 3      \nThink!\n\nIt's the SCSI card doing the DMA t...     51
# 4      1)    I have an old Jasmine drive which I cann...     77
# ...                                                  ...    ...
# 18841  DN> From: nyeda@cnsvax.uwec.edu (David Nye)\nD...     19
# 18842  \nNot in isolated ground recepticles (usually ...    165
# 18843  I just installed a DX2-66 CPU in a clone mothe...     82
# 18844  \nWouldn't this require a hyper-sphere.  In 3-...     28
# 18845  After a tip from Gary Crum (crum@fcom.cc.utah....      6
#
#                                          Name  \
# 0                        0_game_team_games_he
# 1                4_card_monitor_video_drivers
# 2      16_armenian_armenians_turkish_genocide
# 3                     51_scsi_scsi2_scsi1_ide
# 4                  77_tape_backup_tapes_drive
# ...                                       ...
# 18841          19_hiv_patients_medical_doctor
# 18842  165_ground_grounding_conductor_neutral
# 18843                    82_fan_cpu_heat_sink
# 18844         28_den_polygon_points_algorithm
# 18845                  6_car_cars_engine_ford
#
#                                           Representation  \
# 0      [game, team, games, he, players, season, hocke...
# 1      [card, monitor, video, drivers, vga, monitors,...
# 2      [armenian, armenians, turkish, genocide, turke...
# 3      [scsi, scsi2, scsi1, ide, asynchronous, contro...
# 4      [tape, backup, tapes, drive, device, munroe, w...
# ...                                                  ...
# 18841  [hiv, patients, medical, doctor, disease, canc...
# 18842  [ground, grounding, conductor, neutral, wire, ...
# 18843  [fan, cpu, heat, sink, fans, cooling, chip, ho...
# 18844  [den, polygon, points, algorithm, xxxx, polygo...
# 18845  [car, cars, engine, ford, mustang, v8, sho, v6...
#
#                                      Representative_Docs  \
# 0      [As the Sharks' season came to a close tonight...
# 1      [Hello all.\n\tI am thinking about buying an e...
# 2      [\n\nIt is 'Serdar', 'kocaoglan'.\n\n\nJust lo...
# 3      [wlsmith@valve.heart.rri.uwo.ca (Wayne Smith) ...
# 4      [hello all- i have a problem with my micro sol...
# ...                                                  ...
# 18841  [I can not believe the way this thread on cand...
# 18842  [\nNot according to the NEC nor the CEC, as ex...
# 18843  [N(P>Just got a 66MHz 486DX2 system, and am co...
# 18844  [\nSorry!! :-)\n\nCall the four points A, B, C...
# 18845  [\n\n*nnnnnnnng* Thank you for playing, I cann...
#
#                                              Top_n_words  Probability  \
# 0      game - team - games - he - players - season - ...     1.000000
# 1      card - monitor - video - drivers - vga - monit...     1.000000
# 2      armenian - armenians - turkish - genocide - tu...     0.491221
# 3      scsi - scsi2 - scsi1 - ide - asynchronous - co...     0.773688
# 4      tape - backup - tapes - drive - device - munro...     0.663143
# ...                                                  ...          ...
# 18841  hiv - patients - medical - doctor - disease - ...     1.000000
# 18842  ground - grounding - conductor - neutral - wir...     1.000000
# 18843  fan - cpu - heat - sink - fans - cooling - chi...     1.000000
# 18844  den - polygon - points - algorithm - xxxx - po...     1.000000
# 18845  car - cars - engine - ford - mustang - v8 - sh...     0.863232
#
#        Representative_document
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 18841                    False
# 18842                    False
# 18843                    False
# 18844                    False
# 18845                    False
#
# [18846 rows x 8 columns]

# %%
from bertopic.representation import KeyBERTInspired

# Fine-tune your topic representations
representation_model = KeyBERTInspired()
topic_model = BERTopic(representation_model=representation_model)

# %%
from dotenv import load_dotenv
import os
import openai
from bertopic.representation import OpenAI

load_dotenv()
OPENAI_KEY = os.getenv('OPENAI_KEY')


# Fine-tune topic representations with GPT
client = openai.OpenAI(api_key=OPENAI_KEY)
representation_model = OpenAI(client, model="gpt-3.5-turbo", chat=True)
topic_model = BERTopic(representation_model=representation_model)
print(topic_model)
# Out:
# BERTopic(calculate_probabilities=False, ctfidf_model=ClassTfidfTransformer(...), embedding_model=None, hdbscan_model=HDBSCAN(...), language=english, low_memory=False, min_topic_size=10, n_gram_range=(1, 1), nr_topics=None, representation_model=OpenAI(...), seed_topic_list=None, top_n_words=10, umap_model=UMAP(...), vectorizer_model=CountVectorizer(...), verbose=False, zeroshot_min_similarity=0.7, zeroshot_topic_list=None)

# %%
from openai import OpenAI

client = OpenAI(
    # defaults to os.environ.get("OPENAI_API_KEY")
    api_key=OPENAI_KEY,
)

def chat_gpt(prompt):
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}]
    )
    return response.choices[0].message.content.strip()
chat_gpt("how to put Chat GPT into the code I have")
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[36], line 14
#       9     response = client.chat.completions.create(
#      10         model="gpt-4o",
#      11         messages=[{"role": "user", "content": prompt}]
#      12     )
#      13     return response.choices[0].message.content.strip()
# ---> 14 chat_gpt("how to put Chat GPT into the code I have")
#
# Cell In[36], line 9, in chat_gpt(prompt)
#       8 def chat_gpt(prompt):
# ----> 9     response = client.chat.completions.create(
#      10         model="gpt-4o",
#      11         messages=[{"role": "user", "content": prompt}]
#      12     )
#      13     return response.choices[0].message.content.strip()
#
# File ~/.local/lib/python3.12/site-packages/openai/_utils/_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     275             msg = f"Missing required argument: {quote(missing[0])}"
#     276     raise TypeError(msg)
# --> 277 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/openai/resources/chat/completions.py:646, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, service_tier, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     612 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     613 def create(
#     614     self,
#    (...)
#     644     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     645 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 646     return self._post(
#     647         "/chat/completions",
#     648         body=maybe_transform(
#     649             {
#     650                 "messages": messages,
#     651                 "model": model,
#     652                 "frequency_penalty": frequency_penalty,
#     653                 "function_call": function_call,
#     654                 "functions": functions,
#     655                 "logit_bias": logit_bias,
#     656                 "logprobs": logprobs,
#     657                 "max_tokens": max_tokens,
#     658                 "n": n,
#     659                 "parallel_tool_calls": parallel_tool_calls,
#     660                 "presence_penalty": presence_penalty,
#     661                 "response_format": response_format,
#     662                 "seed": seed,
#     663                 "service_tier": service_tier,
#     664                 "stop": stop,
#     665                 "stream": stream,
#     666                 "stream_options": stream_options,
#     667                 "temperature": temperature,
#     668                 "tool_choice": tool_choice,
#     669                 "tools": tools,
#     670                 "top_logprobs": top_logprobs,
#     671                 "top_p": top_p,
#     672                 "user": user,
#     673             },
#     674             completion_create_params.CompletionCreateParams,
#     675         ),
#     676         options=make_request_options(
#     677             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     678         ),
#     679         cast_to=ChatCompletion,
#     680         stream=stream or False,
#     681         stream_cls=Stream[ChatCompletionChunk],
#     682     )
#
# File ~/.local/lib/python3.12/site-packages/openai/_base_client.py:1266, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1252 def post(
#    1253     self,
#    1254     path: str,
#    (...)
#    1261     stream_cls: type[_StreamT] | None = None,
#    1262 ) -> ResponseT | _StreamT:
#    1263     opts = FinalRequestOptions.construct(
#    1264         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1265     )
# -> 1266     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/.local/lib/python3.12/site-packages/openai/_base_client.py:942, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     933 def request(
#     934     self,
#     935     cast_to: Type[ResponseT],
#    (...)
#     940     stream_cls: type[_StreamT] | None = None,
#     941 ) -> ResponseT | _StreamT:
# --> 942     return self._request(
#     943         cast_to=cast_to,
#     944         options=options,
#     945         stream=stream,
#     946         stream_cls=stream_cls,
#     947         remaining_retries=remaining_retries,
#     948     )
#
# File ~/.local/lib/python3.12/site-packages/openai/_base_client.py:1046, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1043         err.response.read()
#    1045     log.debug("Re-raising status error")
# -> 1046     raise self._make_status_error_from_response(err.response) from None
#    1048 return self._process_response(
#    1049     cast_to=cast_to,
#    1050     options=options,
#    (...)
#    1053     stream_cls=stream_cls,
#    1054 )
#
# NotFoundError: Error code: 404 - {'error': {'message': 'The model `gpt-4o` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}
